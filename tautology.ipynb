# %%
a = [True, True, False, False]
b = [True, False, True, False]
A=[]
c = 0

# tautology
def tautology(a):   
    A = []
    p1 = [True, False]
    c = 0


    for i in range(2):
        if p1[i] or (not (p1[i])):
            A.append(True)
        else:
            A.append(False)
    for a in A:
        if not a:
            c += 1

    if c == 0:
        print("It is a tautology")
    if c == len(A):
        print("It is a contradiction")
    if (c > 0) and (c < len(A)):
        print("It is satisfiable")
        

# contradiction
def contradiction(a):
    p1 = [True, False]
    A = []
    c = 0
    for i in range(2):
        if (p1[i] is True) and (not(p1[i]) is False):
            A.append(False)
        elif p1[i] is False:
            A.append(False)
        else:
            A.append(True)

    for a in A:
        if not a:
            c += 1

    print(" P      ~P    P A ~P")
    for a in range(2):
        print("%s  %s  %s"%(p1[a],(not(p1[a])),A[a]))


    if c == 0:
        print("It is a tautology")
    elif c == len(A):
        print("It is a contradiction")
    else:
        print("It is satisfiable")
    
# satisfibilty
def satisfibility(a,b):
    for i in range(4):
        if b[i] is False and a[i] is True:
            A.append(False)
        else:
            A.append(True)
    for f in A:
        if not a:
            c += 1
    print("P      Q      P->Q")
    
    for f in range(4):
        print(a[f],   b[f],   A[f])

# driver code
def menu():
    while (True):
        print("which table you want to display")
        print("tautology table")
        print("contradiction table")
        print("satisfibilty table")
        print("exit the code")
        try:
            choice=int(input("enter your choice :"))   
        except Exception as q:
            print("enter a valid choice")
            
            
        if choice==1:
            tautology(a)
        elif choice==2:
            contradiction(a)
        elif choice==3:
            satisfibility(a,b)
        elif choice==4:
            exit()
            break
        else:
            print("enter the choice given above")
            
                 
menu()
